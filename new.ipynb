# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd


x = np.array([80,85,90,95,100,105,110,115,120])
y = np.array([240,250,260,270,280,290,300,310,320])
plt.title("Sports Watch Data", loc = "left")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.plot(x , y, '*-r')
plt.show()

# %%
x = np.array(["A","B","C","D"])
y = np.random.randint(100,size=(4))
plt.bar(x,y)
# Out:
# <BarContainer object of 4 artists>

# %%
y = np.array([83, 25, 25, 15,77,64,92])


plt.pie(y, labels = ["Amazon", "Flipkart", "Huwaei", "Samsung","Apple","Toyota","Rolex"], explode = [0,0,0,0,0,0,0.1])
plt.show()

# %%
x = np.random.normal(size = (2,3))
print(x)

sns.displot([0,1,2,3,4,5,6], kind="kde")
plt.show()
# Out:
# [[-0.23983277  0.14274294 -1.65953453]
#  [-0.16435847 -0.73598363  0.48095231]]

# %%
sns.displot(np.random.normal(size=1000), kind="kde")
plt.show()

# %%
sns.displot(np.random.poisson(lam=2,size=100))
plt.show()

# %%
def myadd(x , y):
    return x+y

myadd= np.frompyfunc(myadd,2,1)

print(myadd([1,2,3,4],[5,6,7,8]))
print(type(myadd))
# Out:
# [6 8 10 12]
# <class 'numpy.ufunc'>

# %%
a = np.array([2,3])
b = np.array([7,8])
c = np.concatenate((a,b))
print(a)
print(b)
print(c)
# Out:
# [2 3]
# [7 8]
# [2 3 7 8]

# %%
arr1 = np.array([1,2,3,4])
arr2 = np.array([5,6,7,8])
newarr = np.cumprod([arr1,arr2])
print(newarr)
# Out:
# [    1     2     6    24   120   720  5040 40320]

# %%
arr = np.arange(1,11)
x = np.gcd.reduce(arr)
print(x)
# Out:
# 1

# %%
a = [1, 7, 2]
myvar = pd.Series(a)
print(a)
# Out:
# [1, 7, 2]

# %%
data = {
    "calories":[400,350,300,375,800,200],
    "duration":[50,40,30,35,100,25]
}
df = pd.DataFrame(data,index= [1,2,3,4,5,6])
print(df)
print(df.loc[1:5])
# Out:
#    calories  duration
# 1       400        50
# 2       350        40
# 3       300        30
# 4       375        35
# 5       800       100
# 6       200        25
#    calories  duration
# 1       400        50
# 2       350        40
# 3       300        30
# 4       375        35
# 5       800       100

# %%
print(pd.options.display.max_rows)
# Out:
# 60
